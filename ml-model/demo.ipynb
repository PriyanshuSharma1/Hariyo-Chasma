# %%
import torch
import numpy as np
import cv2
import time
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors


class ObjectDetection:
    def __init__(self, source):
        """Initializes an ObjectDetection instance with a video source (webcam or IP camera URL)."""
        self.source = source

        # Model information
        # Load YOLOv8n model weights
        self.model = YOLO(
            "/Users/beyond/Desktop/Projects/hariyo-chasma/ml-model/runs/detect/train/weights/best.pt", task='detect')

        # Visual information
        self.annotator = None
        self.start_time = 0
        self.end_time = 0

        # Device information
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'

    def predict(self, im0):
        """Run prediction using a YOLO model for the input image im0."""
        results = self.model(im0)
        return results

    def display_fps(self, im0):
        """Displays the FPS on an image im0 by calculating and overlaying as white text on a black rectangle."""
        self.end_time = time.time()
        fps = 1 / np.round(self.end_time - self.start_time, 2)
        text = f'FPS: {int(fps)}'
        text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 2)[0]
        gap = 10
        cv2.rectangle(im0, (20 - gap, 70 - text_size[1] - gap),
                      (20 + text_size[0] + gap, 70 + gap), (255, 255, 255), -1)
        cv2.putText(im0, text, (20, 70),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 0), 2)

    def plot_bboxes(self, results, im0):
        """Plots bounding boxes on an image given detection results; returns annotated image and class IDs."""
        class_ids = []
        # Assuming Annotator class exists for visualization
        self.annotator = Annotator(im0, 3, results[0].names)
        boxes = results[0].boxes.xyxy.cpu()
        clss = results[0].boxes.cls.cpu().tolist()
        names = results[0].names
        for box, cls in zip(boxes, clss):
            class_ids.append(cls)
            self.annotator.box_label(box, label=names[int(cls)], color=colors(
                int(cls), True))  # Assuming colors function exists
        return im0, class_ids

    def __call__(self):
        """Executes object detection on video frames from a specified camera index, plotting bounding boxes and returning modified frames."""
        cap = cv2.VideoCapture(self.source)
        assert cap.isOpened()
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
        frame_count = 0
        while True:
            self.start_time = time.time()
            ret, im0 = cap.read()  # im0 is the individual frame.
            assert ret
            results = self.predict(im0)
            im0, class_ids = self.plot_bboxes(results, im0)

            self.display_fps(im0)
            cv2.imshow('Perpetrators Detector', im0)
            frame_count += 1
            if cv2.waitKey(5) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()


# Replace with your IP webcam URL if needed
detector = ObjectDetection(source='http://manishs-ipad.local:8081')

# Call the object detection functionality
detector()

# Check for object detection and send email
# Out:
# 0: 384x640 (no detections), 166.6ms
# Speed: 11.0ms preprocess, 166.6ms inference, 753.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 125.9ms
# Speed: 3.3ms preprocess, 125.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 117.2ms
# Speed: 2.9ms preprocess, 117.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.5ms
# Speed: 5.9ms preprocess, 244.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.0ms
# Speed: 5.4ms preprocess, 133.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.4ms
# Speed: 3.5ms preprocess, 124.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.9ms
# Speed: 3.4ms preprocess, 151.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 142.5ms
# Speed: 3.1ms preprocess, 142.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections),
7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.2ms
# Speed: 3.9ms preprocess, 155.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 181.2ms
# Speed: 4.1ms preprocess, 181.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.5ms
# Speed: 4.1ms preprocess, 160.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.0ms
# Speed: 3.7ms preprocess, 161.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.7ms
# Speed: 3.9ms preprocess, 159.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.3ms
# Speed: 4.2ms preprocess, 158.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.6ms
# Speed: 4.0ms preprocess, 161.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.4ms
# Speed: 4.1ms preprocess, 176.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.3ms
# Speed: 4.1ms preprocess, 177.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 157.2ms
# Speed: 4.0ms preprocess, 157.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.3ms
# Speed: 4.0ms preprocess, 162.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.6ms
# Speed: 3.8ms preprocess, 164.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.5ms
# Speed: 4.5ms preprocess, 156.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.7ms
# Speed: 4.2ms preprocess, 165.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.3ms
# Speed: 4.0ms preprocess, 169.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.5ms
# Speed: 4.5ms preprocess, 147.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.3ms
# Speed: 3.7ms preprocess, 157.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.7ms
# Speed: 4.0ms preprocess, 161.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.4ms
# Speed: 4.2ms preprocess, 159.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 158.7ms
# Speed: 4.1ms preprocess, 158.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.2ms
# Speed: 3.8ms preprocess, 155.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.4ms
# Speed: 3.7ms preprocess, 167.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.1ms
# Speed: 4.8ms preprocess, 170.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.0ms
# Speed: 4.0ms preprocess, 162.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.1ms
# Speed: 4.3ms preprocess, 165.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.2ms
# Speed: 4.2ms preprocess, 157.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carryload, 2 persons, 113.0ms
# Speed: 3.6ms preprocess, 113.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 109.6ms
# Speed: 2.1ms preprocess, 109.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.1ms
# Speed: 2.2ms preprocess, 112.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.3ms
# Speed: 2.2ms preprocess, 155.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 222.5ms
# Speed: 4.0ms preprocess, 222.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.6ms
# Speed: 4.0ms preprocess, 162.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.1ms
# Speed: 4.0ms preprocess, 168.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.2ms
# Speed: 4.0ms preprocess, 179.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.5ms
# Speed: 3.9ms preprocess, 178.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.4ms
# Speed: 3.9ms preprocess, 178.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.8ms
# Speed: 3.7ms preprocess, 170.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.0ms
# Speed: 4.4ms preprocess, 161.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.9ms
# Speed: 4.3ms preprocess, 163.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.1ms
# Speed: 3.8ms preprocess, 159.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 268.8ms
# Speed: 4.6ms preprocess, 268.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.0ms
# Speed: 2.9ms preprocess, 129.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.8ms
# Speed: 2.1ms preprocess, 109.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [http @ 0x16a416340] Stream ends prematurely at 93846387, should be 18446744073709551615
# [mjpeg @ 0x169c2a340] overread 8
# 0: 384x640 (no detections), 225.7ms
# Speed: 2.3ms preprocess, 225.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 85
#      82 detector = ObjectDetection(source='http://manishs-ipad.local:8081')
#      84 # Call the object detection functionality
# ---> 85 detector()
#      87 # Check for object detection and send email
#
# Cell In[18], line 68, in ObjectDetection.__call__(self)
#      66 self.start_time = time.time()
#      67 ret, im0 = cap.read()  # im0 is the individual frame.
# ---> 68 assert ret
#      69 results = self.predict(im0)
#      70 im0, class_ids = self.plot_bboxes(results, im0)
#
# AssertionError:
