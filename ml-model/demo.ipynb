# %%
import numpy as np
import cv2
import time
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
import torch 
from pygame import mixer

class ObjectDetection:
    def __init__(self, source):
        """Initializes an ObjectDetection instance with a video source (webcam or IP camera URL)."""
        self.source = source

        # Model information
        # Load YOLOv8n model weights
        self.model = YOLO("runs/detect/train/weights/best.pt")

        # Visual information
        self.annotator = None
        self.start_time = 0
        self.end_time = 0

        # Device information
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'

    def predict(self, im0):
        """Run prediction using a YOLO model for the input image im0."""
        results = self.model(im0)
        return results
    def alert(self, class_ids):
        """Send an email alert if a person is detected in the frame."""
        for i in class_ids:
            if i == 3:
                # Send email alert
                print("Garbage thrower!")
                
                return True
   

    def display_fps(self, im0):
        """Displays the FPS on an image im0 by calculating and overlaying as white text on a black rectangle."""
        self.end_time = time.time()
        fps = 1 / np.round(self.end_time - self.start_time, 2)
        text = f'FPS: {int(fps)}'
        text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 2)[0]
        gap = 10
        cv2.rectangle(im0, (20 - gap, 70 - text_size[1] - gap),
                      (20 + text_size[0] + gap, 70 + gap), (255, 255, 255), -1)
        cv2.putText(im0, text, (20, 70),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 0), 2)

    def plot_bboxes(self, results, im0):
        """Plots bounding boxes on an image given detection results; returns annotated image and class IDs."""
        class_ids = []
        # Assuming Annotator class exists for visualization
        self.annotator = Annotator(im0, 3, results[0].names)
        boxes = results[0].boxes.xyxy.cpu()
        clss = results[0].boxes.cls.cpu().tolist() # class IDs
        names = results[0].names
        print(names)

        #each box for each class in the image
        for box, cls in zip(boxes, clss): 
            class_ids.append(cls)
            self.annotator.box_label(box, label=names[int(cls)], color=colors(
                int(cls), True))  # Assuming colors function exists

        print(class_ids)
        return im0, class_ids

   
        
        
        
        
        
      
           
            


    def __call__(self):
        """Executes object detection on video frames from a specified camera index, plotting bounding boxes and returning modified frames."""
        cap = cv2.VideoCapture(self.source)
        assert cap.isOpened()
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
        frame_count = 0
        persisting_frames = 0 # Number of frames that give the same alert
        while True:
            self.start_time = time.time()
            ret, im0 = cap.read()  # im0 is the individual frame.
            assert ret
            results = self.predict(im0)
            im0, class_ids = self.plot_bboxes(results, im0) 
            
             
           

            self.display_fps(im0)

            cv2.imshow('Perpetrators Detector', im0)
            mixer.init()
            if(self.alert(class_ids)):
                persisting_frames += 1
                if(persisting_frames % 35 == 0 and persisting_frames > 0): # Save a frame every 35 frames
                    filename = f"frame_{frame_count}.jpg"
                    cv2.imwrite(filename, im0)
                    print(f"Frame saved as: {filename}")
                    mixer.Sound("alert.wav").play()
                    frame_count += 1

            print(class_ids)
            if cv2.waitKey(5) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()


# Replace with your IP webcam URL if needed
detector = ObjectDetection(0)

# Call the object detection functionality
detector()

# Check for object detection and send email
# Out:
# 0: 480x640 1 person, 1515.2ms
# Speed: 19.0ms preprocess, 1515.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 601.5ms
# Speed: 26.0ms preprocess, 601.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 659.0ms
# Speed: 6.0ms preprocess, 659.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 553.0ms
# Speed: 5.0ms preprocess, 553.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 3 persons, 439.0ms
# Speed: 4.0ms preprocess, 439.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0, 3.0]
#
# 0: 480x640 2 persons, 444.0ms
# Speed: 6.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 431.0ms
# Speed: 18.0ms preprocess, 431.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 439.0ms
# Speed: 7.0ms preprocess, 439.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 427.0ms
# Speed: 4.0ms preprocess, 427.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 carryload, 1 person, 433.0ms
# Speed: 4.0ms preprocess, 433.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [0.0, 3.0]
# Garbage thrower!
# [0.0, 3.0]
#
# 0: 480x640 1 carryload, 1 person, 444.0ms
# Speed: 4.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [0.0, 3.0]
# Garbage thrower!
# [0.0, 3.0]
#
# 0: 480x640 1 carryload, 2 persons, 432.0ms
# Speed: 4.0ms preprocess, 432.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [0.0, 3.0, 3.0]
# Garbage thrower!
# [0.0, 3.0, 3.0]
#
# 0: 480x640 2 carryloads, 1 person, 409.0ms
# Speed: 5.0ms preprocess, 409.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [0.0, 3.0, 0.0]
# Garbage thrower!
# [0.0, 3.0, 0.0]
#
# 0: 480x640 2 carryloads, 1 person, 432.0ms
# Speed: 3.0ms preprocess, 432.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 0.0, 0.0]
# Garbage thrower!
# [3.0, 0.0, 0.0]
#
# 0: 480x640 2 persons, 503.0ms
# Speed: 4.0ms preprocess, 503.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 carryload, 1 person, 427.0ms
# Speed: 4.0ms preprocess, 427.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 0.0]
# Garbage thrower!
# [3.0, 0.0]
#
# 0: 480x640 1 person, 428.0ms
# Speed: 3.0ms preprocess, 428.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 455.0ms
# Speed: 4.0ms preprocess, 455.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 426.0ms
# Speed: 4.0ms preprocess, 426.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 415.0ms
# Speed: 3.0ms preprocess, 415.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 415.0ms
# Speed: 3.0ms preprocess, 415.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 535.0ms
# Speed: 3.0ms preprocess, 535.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 446.0ms
# Speed: 4.0ms preprocess, 446.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 459.0ms
# Speed: 4.0ms preprocess, 459.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 430.0ms
# Speed: 4.0ms preprocess, 430.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 409.0ms
# Speed: 4.0ms preprocess, 409.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 441.0ms
# Speed: 5.0ms preprocess, 441.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 415.0ms
# Speed: 3.0ms preprocess, 415.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 437.0ms
# Speed: 3.0ms preprocess, 437.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 444.0ms
# Speed: 3.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 437.0ms
# Speed: 3.0ms preprocess, 437.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 417.0ms
# Speed: 3.0ms preprocess, 417.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 435.0ms
# Speed: 3.0ms preprocess, 435.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 434.0ms
# Speed: 5.0ms preprocess, 434.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 452.0ms
# Speed: 3.0ms preprocess, 452.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 3 persons, 401.0ms
# Speed: 3.0ms preprocess, 401.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0, 3.0]
#
# 0: 480x640 1 person, 414.0ms
# Speed: 3.0ms preprocess, 414.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 431.0ms
# Speed: 3.0ms preprocess, 431.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 430.0ms
# Speed: 4.0ms preprocess, 430.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 409.0ms
# Speed: 4.0ms preprocess, 409.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 418.0ms
# Speed: 5.0ms preprocess, 418.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 433.0ms
# Speed: 3.0ms preprocess, 433.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 431.0ms
# Speed: 4.0ms preprocess, 431.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 409.0ms
# Speed: 3.0ms preprocess, 409.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 430.0ms
# Speed: 5.0ms preprocess, 430.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 3 persons, 429.0ms
# Speed: 3.0ms preprocess, 429.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0, 3.0]
#
# 0: 480x640 1 person, 444.0ms
# Speed: 4.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 436.0ms
# Speed: 3.0ms preprocess, 436.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 444.0ms
# Speed: 3.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 423.0ms
# Speed: 3.0ms preprocess, 423.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# Frame saved as: frame_0.jpg
# [3.0]
#
# 0: 480x640 2 persons, 435.0ms
# Speed: 4.0ms preprocess, 435.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 448.0ms
# Speed: 5.0ms preprocess, 448.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 480.0ms
# Speed: 5.0ms preprocess, 480.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 427.0ms
# Speed: 4.0ms preprocess, 427.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 437.0ms
# Speed: 4.0ms preprocess, 437.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 431.0ms
# Speed: 3.0ms preprocess, 431.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 430.0ms
# Speed: 3.0ms preprocess, 430.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 431.9ms
# Speed: 3.0ms preprocess, 431.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 443.0ms
# Speed: 4.0ms preprocess, 443.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 434.0ms
# Speed: 4.0ms preprocess, 434.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 411.0ms
# Speed: 3.0ms preprocess, 411.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 425.0ms
# Speed: 2.0ms preprocess, 425.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 435.0ms
# Speed: 3.0ms preprocess, 435.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 442.0ms
# Speed: 4.0ms preprocess, 442.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 427.0ms
# Speed: 6.0ms preprocess, 427.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 414.0ms
# Speed: 5.0ms preprocess, 414.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 419.0ms
# Speed: 4.0ms preprocess, 419.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 467.0ms
# Speed: 3.0ms preprocess, 467.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 408.0ms
# Speed: 3.0ms preprocess, 408.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 420.0ms
# Speed: 4.0ms preprocess, 420.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 426.0ms
# Speed: 4.0ms preprocess, 426.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 426.0ms
# Speed: 3.0ms preprocess, 426.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 436.0ms
# Speed: 3.0ms preprocess, 436.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 436.0ms
# Speed: 6.0ms preprocess, 436.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 537.0ms
# Speed: 5.0ms preprocess, 537.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 428.0ms
# Speed: 5.0ms preprocess, 428.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 448.0ms
# Speed: 4.0ms preprocess, 448.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 409.0ms
# Speed: 3.0ms preprocess, 409.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 421.0ms
# Speed: 5.0ms preprocess, 421.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 409.0ms
# Speed: 4.0ms preprocess, 409.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 428.0ms
# Speed: 3.0ms preprocess, 428.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 419.0ms
# Speed: 4.0ms preprocess, 419.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 392.0ms
# Speed: 4.0ms preprocess, 392.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 424.0ms
# Speed: 4.0ms preprocess, 424.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 436.0ms
# Speed: 3.0ms preprocess, 436.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 412.0ms
# Speed: 4.0ms preprocess, 412.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 445.0ms
# Speed: 3.0ms preprocess, 445.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 428.0ms
# Speed: 5.0ms preprocess, 428.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 422.0ms
# Speed: 3.0ms preprocess, 422.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 407.0ms
# Speed: 3.0ms preprocess, 407.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 (no detections), 420.0ms
# Speed: 4.0ms preprocess, 420.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# []
# []
#
# 0: 480x640 1 person, 463.0ms
# Speed: 5.0ms preprocess, 463.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 458.0ms
# Speed: 4.0ms preprocess, 458.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 435.0ms
# Speed: 6.0ms preprocess, 435.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 3 persons, 422.0ms
# Speed: 4.0ms preprocess, 422.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0, 3.0]
#
# 0: 480x640 1 person, 436.0ms
# Speed: 4.0ms preprocess, 436.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 440.0ms
# Speed: 4.0ms preprocess, 440.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 443.0ms
# Speed: 5.0ms preprocess, 443.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 446.0ms
# Speed: 3.0ms preprocess, 446.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 465.0ms
# Speed: 4.0ms preprocess, 465.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 443.0ms
# Speed: 7.0ms preprocess, 443.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# Frame saved as: frame_1.jpg
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 488.9ms
# Speed: 11.0ms preprocess, 488.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 467.0ms
# Speed: 4.0ms preprocess, 467.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 448.0ms
# Speed: 4.0ms preprocess, 448.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 408.0ms
# Speed: 3.0ms preprocess, 408.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 439.0ms
# Speed: 3.0ms preprocess, 439.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 1 person, 446.0ms
# Speed: 3.0ms preprocess, 446.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 458.0ms
# Speed: 3.0ms preprocess, 458.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 425.0ms
# Speed: 3.0ms preprocess, 425.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 455.0ms
# Speed: 4.0ms preprocess, 455.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 445.0ms
# Speed: 3.0ms preprocess, 445.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 444.0ms
# Speed: 4.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 430.0ms
# Speed: 4.0ms preprocess, 430.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 1 person, 410.0ms
# Speed: 5.0ms preprocess, 410.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0]
# Garbage thrower!
# [3.0]
#
# 0: 480x640 2 persons, 429.0ms
# Speed: 3.0ms preprocess, 429.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 421.0ms
# Speed: 4.0ms preprocess, 421.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 422.0ms
# Speed: 6.0ms preprocess, 422.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 439.0ms
# Speed: 3.0ms preprocess, 439.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
#
# 0: 480x640 2 persons, 422.0ms
# Speed: 6.0ms preprocess, 422.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# {0: 'carryload', 1: 'garbage', 2: 'load', 3: 'person'}
# [3.0, 3.0]
# Garbage thrower!
# [3.0, 3.0]
