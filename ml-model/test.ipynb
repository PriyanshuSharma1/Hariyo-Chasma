# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
model = YOLO(
    '/Users/beyond/Desktop/Projects/hariyo-chasma/ml-model/runs/detect/train/weights/best.pt')

# %%
img = "/Users/beyond/Desktop/Projects/hariyo-chasma/ml-model/Hariyo-Chasma-Labelled-Dataset-2/test/images/bags071_jpg.rf.61cefb4898fc5d3e2e6ebd91a0520894.jpg"
result = model(img)
# Out:
# image 1/1 /Users/beyond/Desktop/Projects/hariyo-chasma/ml-model/Hariyo-Chasma-Labelled-Dataset-2/test/images/bags071_jpg.rf.61cefb4898fc5d3e2e6ebd91a0520894.jpg: 640x640 2 carryloads, 2 persons, 1753.6ms
# Speed: 68.5ms preprocess, 1753.6ms inference, 3227.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()

    # Make detections
    results = model(frame)

    # cv2.imshow('YOLO', np.squeeze(results[0].render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 persons, 867.2ms
# Speed: 73.0ms preprocess, 867.2ms inference, 26.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 546.7ms
# Speed: 3.5ms preprocess, 546.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 480.0ms
# Speed: 20.2ms preprocess, 480.0ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 754.0ms
# Speed: 4.2ms preprocess, 754.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 953.6ms
# Speed: 11.0ms preprocess, 953.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1048.0ms
# Speed: 16.5ms preprocess, 1048.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 973.4ms
# Speed: 31.4ms preprocess, 973.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 531.0ms
# ...
